# %%
import random as rnd
import math
import heapq as hq
def Read(filename):
    G = []
    i = 0
    file = open(filename)
    for line in file:
        G.append([float(x) for x in line.split('\t')])
        
        
    return G

CP = Read('dataset.txt')
CP2 = Read('dataset2.txt')
CP3 = Read('dataset3.txt')
CP4 = Read('dataset4.txt')

def distancia(point1, point2):
    return ((point1[0] - point2[0])**2 + (point1[1] - point2[1])**2) ** 0.5

# %%
def Grafito(CPoblados):
    n = len(CPoblados)
    G = [[] for _ in range(n)]
    N = []
    for _ in range(n):
        N.append(_)
    j = -1
    for i in CPoblados:
        auxiliar = CPoblados[:]
        auxiliar.remove(i)
        CantDestNodo = rnd.randint(6,7)
        j +=1
        for _ in range(CantDestNodo):
            dest = rnd.choice(auxiliar)
            auxiliar.remove(dest)
            dist = distancia(i,dest)
            conexion = (dist, int(CPoblados.index(dest)))
            G[j].append(conexion)
    return G


def dijkstra(G, s):
    n = len(G)
    visited = [False]*n
    weights = [math.inf]*n
    path = [None]*n
    queue = []
    weights[s] = 0
    hq.heappush(queue, (0, s))
    while len(queue) > 0:
        g, u = hq.heappop(queue)
        visited[u] = True
        for w, v in G[u]:
            if not visited[v]:
                f = g + w
                if f < weights[v]:
                    weights[v] = f
                    path[v] = u
                    hq.heappush(queue, (f, v))
    return path, weights

# %%
print(dijkstra(Grafito(CP3),0))
# Out:
# ([None, 1145, 1119, 1601, 590, 1302, 395, 1422, 979, 1089, 208, 1225, 174, 270, 1174, 910, 1010, 455, 1405, 1366, 207, 1523, 306, 890, 892, 103, 74, 1576, 996, 8, 670, 1366, 599, 1267, 1083, 903, 1164, 1604, 892, 1117, 772, 1463, 992, 0, 647, 919, 28, 834, 737, 576, 797, 381, 1018, 1599, 476, 626, 1609, 171, 1229, 1077, 1125, 1699, 208, 1397, 566, 369, 933, 1099, 1000, 1236, 1395, 1256, 598, 1523, 24, 1488, 616, 1109, 658, 919, 1489, 798, 92, 1526, 1625, 928, 174, 628, 316, 558, 959, 790, 1658, 1033, 660, 1023, 1010, 800, 334, 1360, 1219, 56, 1169, 0, 1263, 451, 600, 553, 1168, 142, 822, 1555, 1193, 103, 652, 65, 61, 1369, 1579, 1524, 1145, 669, 9, 1494, 1106, 411, 698, 1486, 1198, 316, 154, 323, 1461, 1674, 175, 967, 253, 86, 1089, 1699, 1145, 1595, 1648, 1646, 465, 379, 1427, 259, 1212, 1699, 119, 579, 317, 1259, 1494, 874, 7, 606, 1338, 1157, 850, 1542, 164, 1031, 138, 1361, 1401, 57, 127, 597, 1510, 306, 870, 1650, 919, 1568, 1214, 343, 618, 1099, 1516, 494, 1658, 1632, None, 589, 1293, 542, 1212, 481, 1327, 531, 787, 415, 320, 754, 839, 1474, 119, 996, 394, 480, 507, 1257, 944, 1542, 37, 28, 1413, 1699, 950, 1098, 437, 1715, 1005, 343, 1486, 1524, 113, 1499, 1705, 557, 889, 1418, 1450, 920, 453, 960, 669, 712, 870, 549, 1424, 1273, 1563, 500, 1197, 1056, 315, 1584, 680, 55, 1604, 614, 390, 1173, 306, 615, 95, 769, 1451, 1084, 1130, 171, 1362, 100, 75, 1399, 634, 1338, 164, 1605, 1456, 1692, 1434, 1099, 844, 853, 889, 870, 523, 369, 1